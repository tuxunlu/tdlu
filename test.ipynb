# %%
import dicom2jpg
import os
import pydicom
from pydicom import dcmread

# %%
data_path = '/Volumes/PRO-G40/WUSTL. Unmodified mammograms-selected/'
batch_path = os.path.join(data_path, 'Batch 1')
dicom_img_01 = os.path.join(batch_path, '43-9.dcm')
export_path = os.path.join(data_path, 'export')

# %%
ds = dcmread(dicom_img_01)

# %%
ds.keys()
# Out:
# dict_keys([(0008,0008), (0008,0014), (0008,0016), (0008,0018), (0008,0020), (0008,0023), (0008,0030), (0008,0033), (0008,0050), (0008,0060), (0008,0090), (0008,3010), (0010,0010), (0010,0020), (0010,0030), (0010,0040), (0012,0062), (0012,0064), (0018,0060), (0018,1110), (0018,1111), (0018,1114), (0018,1150), (0018,1151), (0018,1152), (0018,1153), (0018,1164), (0018,1190), (0018,11A0), (0018,11A2), (0018,1405), (0018,1510), (0018,7001), (0018,701A), (0018,7030), (0018,7032), (0018,7052), (0018,7054), (0018,8150), (0020,000D), (0020,000E), (0020,0010), (0020,0011), (0020,0013), (0020,0052), (0020,1002), (0028,0002), (0028,0004), (0028,0010), (0028,0011), (0028,0030), (0028,0100), (0028,0101), (0028,0102), (0028,0103), (0028,0120), (0028,1041), (0028,1050), (0028,1051), (0028,1052), (0028,1053), (0040,0302), (0040,0314), (0040,0316), (0040,8302), (7FE0,0010)])
